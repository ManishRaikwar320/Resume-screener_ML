# %% [markdown]
# # **Resume / Candidate Screening System**

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Load

# %%
resume_text = pd.read_csv("/kaggle/input/datasets/snehaanbhawal/resume-dataset/Resume/Resume.csv")["Resume_str"]
job_description = pd.read_csv("/kaggle/input/datasets/organizations/PromptCloudHQ/us-jobs-on-monstercom/monster_com-job_sample.csv")["job_description"]
print(f"Resume Text: {resume_text.shape} \nJob Description: {job_description.shape}")
# Out:
# Resume Text: (2484,)
# Job Description: (22000,)

# %% [markdown]
# ##### Resume Text Dataset

# %%
resume_text.head()
# Out:
# 0             HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1             HR SPECIALIST, US HR OPERATIONS      ...
# 2             HR DIRECTOR       Summary      Over 2...
# 3             HR SPECIALIST       Summary    Dedica...
# 4             HR MANAGER         Skill Highlights  ...
# Name: Resume_str, dtype: object

# %%
resume_text.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2484 entries, 0 to 2483
# Series name: Resume_str
# Non-Null Count  Dtype
# --------------  -----
# 2484 non-null   object
# dtypes: object(1)
# memory usage: 19.5+ KB

# %% [markdown]
# ##### Job Description

# %%
job_description.head()
# Out:
# 0    TeamSoft is seeing an IT Support Specialist to...
# 1    The Wisconsin State Journal is seeking a flexi...
# 2    Report this job About the Job DePuy Synthes Co...
# 3    Why Join Altec? If you’re considering a career...
# 4    Position ID#  76162 # Positions  1 State  CT C...
# Name: job_description, dtype: object

# %%
job_description.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 22000 entries, 0 to 21999
# Series name: job_description
# Non-Null Count  Dtype
# --------------  -----
# 22000 non-null  object
# dtypes: object(1)
# memory usage: 172.0+ KB

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Missing values check

# %%
print("Resume Text Dataset:")
resume_text.isnull().sum()
# Out:
# Resume Text Dataset:
# np.int64(0)

# %%
print("Job Description Dataset:")
print(job_description.isnull().sum())
print()
print(job_description.shape)
# Out:
# Job Description Dataset:
# 0
#
# (22000,)
